# %%
# %load_ext autoreload

# %autoreload 2
import sys
#sys.path.append("..") 
import numpy as np
from stdogviz import StDoGClient
import igraph as ig
import time
viz = StDoGClient()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
viz.external('http://localhost:5000')
#viz.start()
# Out:
# {'state': 'success', 'msg': "You're inside pyObj room"}

# %%
viz.renderMyImg(width=200, height=200, transparency=False)
# Out:
# {'state': 'success', 'asked to protagonist webclient': 'msg'}

# %%
viz.getImg(0)
# Out:
# 2 Imagens disponíveis. Utilizando a 2
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=179x179 at 0x7F92087C0B70>

# %%
n=600
gsbm = ig.Graph.SBM(n, [[.1, .01, .01],[.01, .1, .01],[.01,.01, .1]],[200, 200 ,200])
pos = np.array(gsbm.layout_fruchterman_reingold_3d(niter=100).coords)
gsbm.vs["pos"] = pos
viz.sendGraph(gsbm, group="main")

# %%
viz.renderMyImg(width=200, height=200, transparency=False)
# Out:
# {'state': 'success', 'asked to protagonist webclient': 'msg'}
# recived img
# {'state': 'success', 'msg': "You're inside pyObj room"}
# {'state': 'success', 'msg': "You're inside pyObj room"}

# %%
#time.sleep(2)
viz.getImg(-1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=179x179 at 0x7F92518DE6D8>

# %%
viz.updateNodePostions(pos, group="er")

# %%
pos = np.array(g.layout_circle().coords)
pos = np.concatenate([pos, np.zeros(shape=(n, 1))], axis=1)
pos[0]
# Out:
# array([1., 0., 0.])

# %%
pos = np.array(ger.layout_fruchterman_reingold(niter=100).coords)
pos = np.concatenate([pos, np.zeros(shape=(n, 1))], axis=1)
pos[0]
viz.updateNodePostions(pos, group="main")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-25b5e2746c96> in <module>
#       1 pos = np.array(ger.layout_fruchterman_reingold(niter=100).coords)
# ----> 2 pos = np.concatenate([pos, np.zeros(shape=(n, 1))], axis=1)
#       3 pos[0]
#       4 viz.updateNodePostions(pos, group="main")
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 1000 and the array at index 1 has size 600

# %%
pos = np.array(gsbm.layout_fruchterman_reingold(niter=1000).coords)
pos = np.concatenate([pos, np.ones(shape=(n, 1))], axis=1)
pos[0]
viz.updateNodePostions(pos, group="sbm")

# %%
from sznajd import get_evo_state

# %%
degrees = np.array([1/d for d in g.degree()], dtype=np.float32)
edges =  np.array([[e.source, e.target]for e in g.es], dtype=np.int32)
n = g.vcount()
n_edges = len(edges)
n_temps = 1000
w = 0.1
state = np.random.choice(
    [0, 1],size= n,p=[.5, .5]).astype(dtype=np.int32)
colors = cm.get_cmap('viridis', n)(state.copy().astype("float"))[:,0:3]

viz.updateNodeColors(colors)
np.unique(colors[:,0])
# Out:
# array([0.267004, 0.993248])

# %%
import time
for i in range(100):
    state = get_evo_state(degrees, edges, n,3,n_edges,state,n_temps,w)
    #state = np.array(state, dtype=np.int32)
    state = np.random.uniform(size=n)
    colors = cm.get_cmap(
        'viridis', n)(state.astype("float"))[:,0:3]
    #state = np.array(state, dtype=np.int32)
    viz.updateNodeColors(colors)
    time.sleep(0.1)

# %%
viz.renderMyImg( transparency=True)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x220 at 0x7F85A454E1D0>
# {'state': 'success', 'asked to protagonist webclient': 'msg'}
# recived img
# recived img

# %%
viz.getImg()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x220 at 0x7F85A454EC50>
# {'state': 'success', 'msg': "You're inside pyObj room"}
# {'state': 'success', 'msg': "You're inside pyObj room"}
# {'state': 'success', 'msg': "You're inside pyObj room"}
# {'state': 'success', 'msg': "You're inside pyObj room"}
# {'state': 'success', 'msg': "You're inside pyObj room"}
# {'state': 'success', 'msg': "You're inside pyObj room"}

# %%
import igraph as ig
n=1000
g = ig.Graph.Barabasi(n, 3)

# %%
coords = g.layout_fruchterman_reingold_3d(niter = 100)

# %%
import igraph as ig
n=1000
g = ig.Graph.Barabasi(n, 3)

sio.sendGraph(g)
# Out:
# {'state': 'success', 'msg': 'graph recived'}

# %%
sio.renderMyImg( transparency=True)
sio.getImg()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x220 at 0x7F73D58EBEF0>
# {'state': 'success', 'asked to protagonist webclient': 'msg'}
# recived img

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
n = g.vcount()
degree = g.degree()
colors = cm.get_cmap('viridis', n)(degree)[:,0:3]
colors[:,0:3].flatten()
# Out:
# array([0.283229, 0.120777, 0.440584, ..., 0.267004, 0.004874, 0.329415])

# %%
sio.updateNodeColors(colors)

# %%
colors
# Out:
# array([[0.283229, 0.120777, 0.440584],
#        [0.281446, 0.08432 , 0.407414],
#        [0.28291 , 0.105393, 0.426902],
#        ...,
#        [0.267004, 0.004874, 0.329415],
#        [0.267004, 0.004874, 0.329415],
#        [0.267004, 0.004874, 0.329415]])

# %%
sio.renderMyImg( transparency=True)
sio.getImg()

# %%
import pickle
State = {}
g = pickle.load(open("../stdogvis/bin/graph.ml", "rb"))
